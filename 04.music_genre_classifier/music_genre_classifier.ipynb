# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Шаг-1.-Откроем-файлы-с-данными" data-toc-modified-id="Шаг-1.-Откроем-файлы-с-данными-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Шаг 1. Откроем файлы с данными</a></span><ul class="toc-item"><li><span><a href="#Рассмотрим-данные-тренировочной-выборке" data-toc-modified-id="Рассмотрим-данные-тренировочной-выборке-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Рассмотрим данные тренировочной выборке</a></span></li><li><span><a href="#Посмотрим-на-дубликаты-без-таргета" data-toc-modified-id="Посмотрим-на-дубликаты-без-таргета-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Посмотрим на дубликаты без таргета</a></span></li><li><span><a href="#Корреляция" data-toc-modified-id="Корреляция-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Корреляция</a></span></li><li><span><a href="#Рассмотрим-данные-тестовой-выборки" data-toc-modified-id="Рассмотрим-данные-тестовой-выборки-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Рассмотрим данные тестовой выборки</a></span></li><li><span><a href="#Корреляция" data-toc-modified-id="Корреляция-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Корреляция</a></span></li></ul></li><li><span><a href="#Шаг-2.-Предобработка-и-исследовательский-анализ-данных" data-toc-modified-id="Шаг-2.-Предобработка-и-исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Шаг 2. Предобработка и исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Удалим-ненужные-столбцы" data-toc-modified-id="Удалим-ненужные-столбцы-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Удалим ненужные столбцы</a></span></li><li><span><a href="#Рассмотрим-пропуска-в-данных" data-toc-modified-id="Рассмотрим-пропуска-в-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Рассмотрим пропуска в данных</a></span><ul class="toc-item"><li><span><a href="#Data-train" data-toc-modified-id="Data-train-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Data train</a></span></li><li><span><a href="#Data-test" data-toc-modified-id="Data-test-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Data test</a></span></li></ul></li><li><span><a href="#Рассмотрим-данные" data-toc-modified-id="Рассмотрим-данные-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Рассмотрим данные</a></span><ul class="toc-item"><li><span><a href="#Категориальные-признаки" data-toc-modified-id="Категориальные-признаки-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Категориальные признаки</a></span></li><li><span><a href="#Числовые-признаки" data-toc-modified-id="Числовые-признаки-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Числовые признаки</a></span></li><li><span><a href="#Data-test" data-toc-modified-id="Data-test-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Data test</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-корреляцию-по-жанрам-признаком-instrumentalness-и-speechiness" data-toc-modified-id="Посмотрим-на-корреляцию-по-жанрам-признаком-instrumentalness-и-speechiness-2.3.3.1"><span class="toc-item-num">2.3.3.1&nbsp;&nbsp;</span>Посмотрим на корреляцию по жанрам признаком instrumentalness и speechiness</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Шаг-3.-Разработка-модели-ML" data-toc-modified-id="Шаг-3.-Разработка-модели-ML-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Шаг 3. Разработка модели ML</a></span><ul class="toc-item"><li><span><a href="#Посмотрим-на-баланс-классов" data-toc-modified-id="Посмотрим-на-баланс-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Посмотрим на баланс классов</a></span></li><li><span><a href="#Подготовим-выборку" data-toc-modified-id="Подготовим-выборку-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подготовим выборку</a></span></li><li><span><a href="#Создадим-pipeline" data-toc-modified-id="Создадим-pipeline-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Создадим pipeline</a></span></li><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>LogisticRegression</a></span></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#CatBoostClassifier" data-toc-modified-id="CatBoostClassifier-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>CatBoostClassifier</a></span></li><li><span><a href="#Cобирем-результаты-всех-моделей-в-таблицу" data-toc-modified-id="Cобирем-результаты-всех-моделей-в-таблицу-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Cобирем результаты всех моделей в таблицу</a></span></li><li><span><a href="#Проверим-значимость-параметров" data-toc-modified-id="Проверим-значимость-параметров-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Проверим значимость параметров</a></span></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><span><a href="#Протестируем-модель" data-toc-modified-id="Протестируем-модель-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Протестируем модель</a></span></li><li><span><a href="#Делаем-предсказания-на-тестовая-выборке" data-toc-modified-id="Делаем-предсказания-на-тестовая-выборке-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Делаем предсказания на тестовая выборке</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Kлассифицикация музыкальных произведения по жанрам

# %% [markdown]
# __Задача:__
#
# Разработать модель, позволяющую классифицировать музыкальные произведения по жанрам.
#
# __Метрика:__
#
# Необходимо максимизировать метрику f1_micro, которая вычисляется по формуле:
# $$
# {F1 micro} = 2 * \frac{{𝑀𝑖𝑐𝑟𝑜𝑃𝑟𝑒𝑐𝑖𝑠𝑖𝑜𝑛∗𝑀𝑖𝑐𝑟𝑜𝑅𝑒𝑐𝑎𝑙𝑙}} {Micro Precision + Micro Recall}
# $$
#
# __Данные:__
#
# 1) train.csv - тренировочный набор данных о музыкальных треках, которые будут использоваться в качестве обучающих данных. Количество записей 20394 и 16 признаков.
#
# 2) test.csv - тестовый набор данных о музыкальных треках, которые будут использоваться в качестве тестовых данных. Количество записей 5099 и 16 признаков.
#
# 3) sample_submit.csv - файл предсказаний в правильном формате.
#
# 4) instance_id - идентификатор трека в тестовом наборе test.csv.
#
# 5) music_genre - целевой признак.
#
#
# __План работы:__
#
#  -  Загрузка библиотек.
#  - Установка параметров проекта.
#  - Ознакомление с данными.
#  - Анализ и редобработка данных.
#  - Обучение разных модели, подбор мараметров и нахождение лучшей.
#  - Тестирование модели.

# %%
# импортируем библиотеки
import pandas as pd 
import phik
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import optuna
import shap

from phik.report import plot_correlation_matrix
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.compose import ColumnTransformer 
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import f1_score
from optuna.samplers import TPESampler
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')

# %%
# константы
RANDOM_STATE=42

# %%
# Устанавливаю отображение столбцов при выводе датафрейма
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Шаг 1. Откроем файлы с данными

# %%
# %%time
# загружаю данные и смотрю на время работы яцейки
try:
    train = pd.read_csv('/Users/tanya/Documents/DS/Projects/kaggle_music_genre/kaggle_music_genre_train.csv',\
                        index_col='instance_id')
except:
       pass
# Out:
# CPU times: user 81.3 ms, sys: 18.5 ms, total: 99.8 ms
# Wall time: 104 ms

# %%
# %%time
# загружаю данные и смотрю на время работы яцейки
try:
    test = pd.read_csv('/Users/tanya/Documents/DS/Projects/kaggle_music_genre/kaggle_music_genre_test.csv',\
                      index_col='instance_id')
except:
       pass
# Out:
# CPU times: user 26 ms, sys: 6.38 ms, total: 32.4 ms
# Wall time: 37.5 ms

# %%
#делаем столбец instance_id индексом
train.index.names = [None]
test.index.names = [None]

# %%
# функция для изучения данных
def info(df):
    display(df.info())
    display(df.describe().T)
    display(df.sample(5))
    print('Количество дубликатов в данных:', df.duplicated().sum())
    print(f'Количество столбцов: {df.shape[1]}, число записей: {df.shape[0]}')

# %%
# Создадим копию df
temp_train = train.copy()
temp_test = test.copy()

# %% [markdown]
# __проверим распределения в тестовой и тренировочной выборках__

# %% [markdown]
# ### Рассмотрим данные тренировочной выборке

# %%
# тренировочная выборка
info(train)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 20394 entries, 25143.0 to 86375.0
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        20394 non-null  object
#  1   acousticness      20394 non-null  float64
#  2   danceability      20394 non-null  float64
#  3   duration_ms       20394 non-null  float64
#  4   energy            20394 non-null  float64
#  5   instrumentalness  20394 non-null  float64
#  6   key               19659 non-null  object
#  7   liveness          20394 non-null  float64
#  8   loudness          20394 non-null  float64
#  9   mode              19888 non-null  object
#  10  speechiness       20394 non-null  float64
#  11  tempo             19952 non-null  float64
#  12  obtained_date     20394 non-null  object
#  13  valence           20394 non-null  float64
#  14  music_genre       20394 non-null  object
# dtypes: float64(10), object(5)
# ...

# %%
# удалим явные дубликаты
train.drop_duplicates(inplace=True)

# %%
# рассмотрим уникальные значения кат. столбцов
print(train['key'].unique())
print(train['mode'].unique())
print(train['obtained_date'].unique())
print(train['music_genre'].unique())
# Out:
# ['D' 'A' 'E' 'G#' 'C' 'D#' 'A#' 'F' 'F#' nan 'G' 'C#' 'B']
# ['Major' 'Minor' nan]
# ['4-Apr' '3-Apr' '5-Apr' '1-Apr']
# ['Country' 'Rock' 'Alternative' 'Hip-Hop' 'Blues' 'Jazz' 'Electronic'
#  'Anime' 'Rap' 'Classical']

# %%
# сделаем синтетичемский признак из назвавния песен по длинне символов
train['len_track_name'] = train['track_name'].transform(lambda x: len(x))
test['len_track_name'] = test['track_name'].transform(lambda x: len(x))

# %% [markdown]
# ### Посмотрим на дубликаты без таргета

# %%
# признаки
features = ['track_name',
            'danceability',
            'acousticness',
            'danceability',
            'duration_ms',
            'energy',
            'instrumentalness',
            'key',
            'liveness',
            'loudness',
            'mode',
            'speechiness',
            'tempo',
            'valence']

# %%
# дубликаты без таргета
train[train.duplicated(subset=features)]
# Out:
#                            track_name  acousticness  danceability  \
# 23587.0         First Person on Earth      0.228000         0.454
# 84391.0                     The Bends      0.038100         0.512
# 79141.0                everybody dies      0.300000         0.617
# 49551.0               bernard trigger      0.000449         0.400
# 57824.0                    Crack Rock      0.088400         0.564
# ...                               ...           ...           ...
# 72215.0              Beyond The Stars      0.000007         0.406
# 42562.0                  Be My Escape      0.006050         0.554
# 66420.0                    Trap Queen      0.024400         0.746
# 27588.0  アシタカとサン - Piano Solo Feature      0.975000         0.338
# 43672.0                        1 on 1      0.000525         0.905
#
#          duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 23587.0     173448.0   0.804          0.000000   E     0.181    -5.225  Minor
# ...

# %%
# удалим дубликаты
train = train.drop_duplicates(subset=features)

# %% [markdown]
# ### Корреляция

# %%
#удалим колонку track_name она мешает просмотру корреляции, сделаем из нее эмбединги
data_train = train.drop(['track_name'], axis=1)

# %%
# проверка на мультиколлинеарность
phik_overview_train = data_train.phik_matrix(interval_cols=['acousticness', 
                                                            'danceability', 
                                                            'duration_ms', 
                                                            'energy', 
                                                            'instrumentalness', 
                                                            'liveness', 
                                                            'loudness', 
                                                            'speechiness', 
                                                            'tempo', 
                                                            'valence'])
phik_overview_train.round(2)
# Out:
#                   acousticness  danceability  duration_ms  energy  \
# acousticness              1.00          0.46         0.13    0.77
# danceability              0.46          1.00         0.17    0.52
# duration_ms               0.13          0.17         1.00    0.14
# energy                    0.77          0.52         0.14    1.00
# instrumentalness          0.44          0.34         0.17    0.44
# key                       0.10          0.10         0.04    0.09
# liveness                  0.19          0.14         0.09    0.26
# loudness                  0.71          0.48         0.17    0.84
# mode                      0.03          0.10         0.01    0.03
# speechiness               0.20          0.33         0.03    0.24
# tempo                     0.34          0.41         0.08    0.39
# obtained_date             0.26          0.29         0.04    0.29
# valence                   0.40          0.53         0.14    0.48
# ...

# %%
# граффик кореляции
plot_correlation_matrix(phik_overview_train.values,
                       x_labels = phik_overview_train.columns,
                       y_labels = phik_overview_train.index,
                       vmin=0, vmax=1, color_map='Blues',
                       title='Correlation',
                       fontsize_factor=1.5,
                       figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
# граффик стат значимости
significance_overview_train = data_train.significance_matrix(interval_cols=['acousticness', 
                                                            'danceability', 
                                                            'duration_ms', 
                                                            'energy', 
                                                            'instrumentalness', 
                                                            'liveness', 
                                                            'loudness', 
                                                            'speechiness', 
                                                            'tempo', 
                                                            'valence'])
plot_correlation_matrix(significance_overview_train.fillna(0).values,
                       x_labels=significance_overview_train.columns,
                       y_labels=significance_overview_train.index,
                       vmin=-5, vmax=5, title='Significance of the coefficients',
                       usetex=False, fontsize_factor=1.5 , figsize=(15, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# __Вывод:__
# Тренировочных данные:
# 1) Есть пропуска, стоит изучить возмодность их заполнения или удаления.
#
# 2) Тип данных соответствует.
#
# 3) Имеются аномальные значения в колонке длительность.
#
# 4) Мультиколленираность присутствует в данных.
#
# 5) В данных есть дубликаты, если не учитывать столбец music_genre. УБрали эти данные, это явная ошибка заполнения дата-сета.
#
# 5) Некоторые колонки стоит удалить. А именно track_name, obtained_date. Они нам не помогут в прогнозах.

# %% [markdown]
# ### Рассмотрим данные тестовой выборки

# %%
# тестовые данные
info(test)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5099 entries, 48564 to 47986
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_name        5099 non-null   object
#  1   acousticness      5099 non-null   float64
#  2   danceability      5099 non-null   float64
#  3   duration_ms       5099 non-null   float64
#  4   energy            5099 non-null   float64
#  5   instrumentalness  5099 non-null   float64
#  6   key               4941 non-null   object
#  7   liveness          5099 non-null   float64
#  8   loudness          5099 non-null   float64
#  9   mode              4950 non-null   object
#  10  speechiness       5099 non-null   float64
#  11  tempo             4978 non-null   float64
#  12  obtained_date     5099 non-null   object
#  13  valence           5099 non-null   float64
#  14  len_track_name    5099 non-null   int64
# dtypes: float64(10), int64(1), object(4)
# ...

# %%
print(test['key'].unique())
print(test['mode'].unique())
print(test['obtained_date'].unique())
# Out:
# ['A#' 'G#' 'A' 'B' 'D' 'F#' 'F' 'G' 'C' nan 'D#' 'C#' 'E']
# ['Minor' 'Major' nan]
# ['4-Apr' '3-Apr' '5-Apr' '1-Apr']

# %% [markdown]
# ### Корреляция

# %%
#удалим колонку track_name она мешает просмотру корреляции, сделаем из нее эибедингии позже
data_test= test.drop(['track_name'], axis=1)

# %%
# проверка на мультиколлинеарность
phik_overview_test = data_test.phik_matrix(interval_cols=['acousticness', 
                                                            'danceability', 
                                                            'duration_ms', 
                                                            'energy', 
                                                            'instrumentalness', 
                                                            'liveness', 
                                                            'loudness', 
                                                            'speechiness', 
                                                            'tempo', 
                                                            'valence'])
phik_overview_test.round(2)
# Out:
#                   acousticness  danceability  duration_ms  energy  \
# acousticness              1.00          0.43         0.23    0.77
# danceability              0.43          1.00         0.25    0.52
# duration_ms               0.23          0.25         1.00    0.24
# energy                    0.77          0.52         0.24    1.00
# instrumentalness          0.44          0.35         0.35    0.46
# key                       0.09          0.11         0.00    0.08
# liveness                  0.17          0.13         0.18    0.26
# loudness                  0.70          0.48         0.33    0.85
# mode                      0.04          0.06         0.06    0.06
# speechiness               0.21          0.34         0.00    0.24
# tempo                     0.31          0.41         0.11    0.35
# obtained_date             0.26          0.29         0.11    0.31
# valence                   0.38          0.54         0.23    0.47
# ...

# %%
# граффик кореляции
plot_correlation_matrix(phik_overview_test.values,
                       x_labels = phik_overview_test.columns,
                       y_labels = phik_overview_test.index,
                       vmin=0, vmax=1, color_map='Blues',
                       title='correlation',
                       fontsize_factor=1.5,
                       figsize=(12, 8))
plt.tight_layout()
plt.show()

# %%
# граффик стат значимости
significance_overview_test = data_test.significance_matrix(interval_cols=['acousticness', 
                                                            'danceability', 
                                                            'duration_ms', 
                                                            'energy', 
                                                            'instrumentalness', 
                                                            'liveness', 
                                                            'loudness', 
                                                            'speechiness', 
                                                            'tempo', 
                                                            'valence'])
plot_correlation_matrix(significance_overview_test.fillna(0).values,
                       x_labels=significance_overview_test.columns,
                       y_labels=significance_overview_test.index,
                       vmin=-5, vmax=5, title='Significance of the coefficients',
                       usetex=False, fontsize_factor=1.5 , figsize=(15, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# __Вывод:__
# Тестовые данные:
# 1) Есть пропуска, стоит изучить возмодность их заполнения или удаления.
#
# 2) Тип данных соответствует.
#
# 3) Имеются аномальные значения в колонке длительность.
#
# 4) Мультиколленираность присутствует в данных.
#
# 5) Столбец  obtained_date стоит удалить. Он нам не помогут в прогнозах.
#
# 6) Из столбца с название треков, сделаем эмбединги.

# %% [markdown]
# ## Шаг 2. Предобработка и исследовательский анализ данных

# %% [markdown]
# ### Удалим ненужные столбцы

# %%
# Столбцы: obtained_date нам не понадобятся для пострения модели
data_train = data_train.drop(['obtained_date'], axis=1)
data_test = data_test.drop(['obtained_date'], axis=1)

# %%
print(temp_train.shape)
print(data_train.shape)
print(temp_test.shape)
print(data_test.shape)
# Out:
# (20394, 15)
# (19909, 14)
# (5099, 14)
# (5099, 13)

# %% [markdown]
# ### Рассмотрим пропуска в данных

# %% [markdown]
# #### Data train

# %%
# пропуска в key
display(data_train[data_train['key'].isna()].head())
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 87453.0        0.9910         0.154         -1.0  0.0384          0.902000
# 87796.0        0.7470         0.478     294973.0  0.3950          0.000005
# 69398.0        0.2490         0.389     211851.0  0.4310          0.000000
# 20134.0        0.0145         0.580     201694.0  0.7200          0.598000
# 69505.0        0.1560         0.563     191760.0  0.8970          0.000000
#
#          key  liveness  loudness   mode  speechiness    tempo  valence  \
# 87453.0  NaN     0.109   -26.909  Major       0.0405   68.199   0.0393
# 87796.0  NaN     0.264    -7.917  Major       0.2130   74.515   0.1700
# 69398.0  NaN     0.130    -8.061  Major       0.0344  142.140   0.2750
# 20134.0  NaN     0.281    -5.541  Major       0.0638  143.816   0.1600
# 69505.0  NaN     0.352    -4.996  Major       0.2130  157.803   0.7790
#
#         music_genre  len_track_name
# 87453.0   Classical              51
# ...

# %%
# сделаем копию датасета и посмотрим на пропуска c заполнением
data_train_nan = data_train.copy()
# заполним пропуска категорией 'other', посмотрим как запределена зависимость по жанрам
data_train_nan['key'].fillna('other', inplace=True)

# %%
# заполним пропуска категорией 'other', посмотрим как запределена зависимость по жанрам
median = data_train['tempo'].median()
data_train_nan['tempo'].fillna(median, inplace=True)

# %%
# построим граффик зависимость ключей от жанров
vis_1 = data_train_nan.groupby('key')['music_genre'].value_counts()
plt.figure(figsize=(20, 10))
vis_1.unstack(0).plot(kind='bar', ylabel='count', title='Зависимость ключей от жанров')
plt.legend(loc='upper right' , bbox_to_anchor=(1.2, 1.0))
plt.show()

# %%
print(vis_1)
# Out:
# key    music_genre
# A      Blues          367
#        Rock           243
#        Country        241
#        Alternative    228
#        Electronic     218
#                      ...
# other  Country         76
#        Anime           67
#        Hip-Hop         46
#        Jazz            42
#        Classical       40
# Name: music_genre, Length: 130, dtype: int64

# %% [markdown]
# __Вывод:__ Четкой взаимостязи ключей от жанров увидеть неудалось. Так же очевидно, что композиций в жанре Blues у нас больше всего, а в жанре Hip-Hop меньше всего. Проверим это дальше.

# %%
data_train['key'].isna().sum()
# Out:
# 735

# %%
# пропуска в mode
display(data_train[data_train['mode'].isna()].head())
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 63867.0      0.973000         0.416     401000.0  0.0735          0.710000
# 75913.0      0.926000         0.495         -1.0  0.1110          0.120000
# 64391.0      0.526000         0.731     236173.0  0.6080          0.000000
# 37649.0      0.000216         0.555      50472.0  0.9530          0.059400
# 43825.0      0.287000         0.689     285263.0  0.6200          0.000002
#
#         key  liveness  loudness mode  speechiness    tempo  valence  \
# 63867.0   F    0.0781   -20.723  NaN       0.0411  112.006    0.222
# 75913.0  C#    0.0772   -18.591  NaN       0.0506   78.772    0.436
# 64391.0   G    0.1260   -10.690  NaN       0.0267  126.263    0.745
# 37649.0   E    0.8180    -4.411  NaN       0.1090  114.885    0.303
# 43825.0   G    0.0368   -10.601  NaN       0.0339  110.860    0.962
#
#         music_genre  len_track_name
# 63867.0   Classical              74
# ...

# %%
# заполним пропуска категорией 'other', посмотрим как запределена зависимость по жанрам
data_train_nan['mode'].fillna('other', inplace=True)

# %%
vis_2 = data_train_nan.groupby('mode')['music_genre'].value_counts()
plt.figure(figsize=(15, 10))
vis_2.unstack(0).plot(kind='bar', ylabel='count', title='Модальность модальность от жанра')
plt.legend(loc='upper right' , bbox_to_anchor=(1.2, 1.0))
plt.show()

# %% [markdown]
# __Вывод:__ Компазиции с мажорной модальностью у нас явно больше. Четкое разделение модальностей по жанрам не прослеживается. В целом во всех жанрах преобладают комназиции с мажорной модальностью.

# %%
# пропуска в tempo
display(data_train[data_train['tempo'].isna()].head())
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 45966.0      0.287000         0.476     212427.0   0.612          0.000252
# 90217.0      0.000059         0.489     269000.0   0.947          0.000000
# 79170.0      0.348000         0.698     362267.0   0.800          0.000087
# 39716.0      0.008340         0.776     191210.0   0.783          0.044900
# 48590.0      0.001100         0.608     178440.0   0.801          0.000008
#
#         key  liveness  loudness   mode  speechiness  tempo  valence  \
# 45966.0   A    0.0877    -7.010  Major       0.0335    NaN    0.909
# 90217.0  C#    0.1130    -3.925  Minor       0.0419    NaN    0.517
# 79170.0   B    0.4430    -3.091  Minor       0.0284    NaN    0.654
# 39716.0   C    0.0377    -3.595  Major       0.0374    NaN    0.943
# 48590.0   A    0.2230    -5.452  Minor       0.0376    NaN    0.544
#
#          music_genre  len_track_name
# 45966.0         Rock              13
# ...

# %%
# заполним пропуска категорией 'other', посмотрим как запределена зависимость по жанрам
median = data_train['tempo'].median()
data_train_nan['tempo'].fillna(median, inplace=True)

# %% [markdown]
# #### Data test

# %%
# пропуска в key
display(data_test[data_test['key'].isna()].head())
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 58160      0.000901         0.769     215294.0   0.792           0.00000  NaN
# 61070      0.852000         0.610     401493.0   0.150           0.85900  NaN
# 29197      0.000928         0.607     200000.0   0.912           0.00835  NaN
# 90739      0.501000         0.674     212312.0   0.676           0.00135  NaN
# 87402      0.302000         0.749         -1.0   0.637           0.00417  NaN
#
#        liveness  loudness   mode  speechiness    tempo  valence  \
# 58160    0.3850    -4.086  Major       0.1110  136.021    0.295
# 61070    0.1060   -20.559  Minor       0.0352  104.815    0.205
# 29197    0.1570    -3.867  Minor       0.1310  150.051    0.172
# 90739    0.3730    -7.677  Minor       0.2330  103.997    0.549
# 87402    0.0705    -8.455  Major       0.0680  139.988    0.335
#
#        len_track_name
# 58160               7
# 61070              21
# 29197               7
# ...

# %%
# пропуска в mode
display(data_test[data_test['mode'].isna()].head())
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 41832      0.000707         0.365     248587.0   0.751          0.000000   D
# 49131      0.062700         0.286     325627.0   0.547          0.000003   E
# 34229      0.781000         0.458     149800.0   0.290          0.162000   G
# 72374      0.018900         0.548     356813.0   0.631          0.001250  C#
# 72531      0.253000         0.429     419533.0   0.517          0.000006   C
#
#        liveness  loudness mode  speechiness    tempo  valence  len_track_name
# 41832     0.318    -5.429  NaN       0.3040   79.119    0.604              13
# 49131     0.112    -7.923  NaN       0.0318  174.717    0.453               8
# 34229     0.568   -13.498  NaN       0.0371  136.404    0.405              30
# 72374     0.368    -7.079  NaN       0.0265  104.029    0.340               9
# 72531     0.984    -8.352  NaN       0.0328  102.180    0.306              23

# %%
# пропуска в tempo
display(data_test[data_test['tempo'].isna()].head())
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 79753       0.98100         0.174     287360.0  0.0289          0.829000   G
# 27331       0.09840         0.611     142013.0  0.4490          0.000000   D
# 34855       0.38300         0.616     184033.0  0.4090          0.000000  C#
# 43840       0.00360         0.528     241293.0  0.8250          0.000002   B
# 79286       0.00001         0.276     228640.0  0.9620          0.000366   B
#
#        liveness  loudness   mode  speechiness  tempo  valence  len_track_name
# 79753    0.0817   -25.038  Major       0.0391    NaN   0.0315              19
# 27331    0.2260    -8.938  Minor       0.2940    NaN   0.2240              11
# 34855    0.1400    -8.427  Major       0.2980    NaN   0.4530               8
# 43840    0.3690    -4.740  Minor       0.0602    NaN   0.4090              31
# 79286    0.0327    -3.797  Minor       0.0629    NaN   0.7410               8

# %%
print(temp_train.shape)
print(data_train.shape)
print(temp_test.shape)
print(data_test.shape)
# Out:
# (20394, 15)
# (19909, 14)
# (5099, 14)
# (5099, 13)

# %% [markdown]
# __Вывод:__ Заполним все пропуска в данные спомощью imputer в pipeline.

# %% [markdown]
# ### Рассмотрим данные

# %% [markdown]
# #### Категориальные признаки

# %%
# функция для построения граффиков
def make_cat_col_sns(data):
    for col in data[hist_cols]:
        plt.figure(figsize=(8,5))
        sns.histplot(data=data, x=data[col], bins=31, hue='music_genre')
        plt.xlabel('music_genre')
        plt.ylabel(col)
        plt.title('Гистограммы распределения ' + col + ' по жанрам.')
        plt.show()

# %%
# отбираем категориальные признаки
hist_cols = ['key', 'mode', 'len_track_name']

# строим граффик
make_cat_col_sns(data_train_nan)

# %% [markdown]
# __Вывод:__
# 1) Четких распределений ключей по жанрам установить невозможно. Стоит подумать по поводу удаления этого столбца, после изучения выжности признаков
#
# 2) В данный явно предладают данные с major модальностью. Их больше приерно на 70%.
#
# 3) Судя по всему более длинныц треки характерны для классической музыки, а более короткие для альтернативы.

# %% [markdown]
# #### Числовые признаки

# %%
# напишем функцию для гистограммы и boxplot
def show_num_features(df, col_title, num_bins):
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    axes[0].set_title(col_title + '. Плотность распределения', fontsize=16)
    axes[0].set_ylabel('плотность')
    axes[1].set_title(col_title + '. boxplot', fontsize=16)
    axes[1].set_ylabel('значения')
    sns.histplot(df, bins=num_bins, ax=axes[0])
    sns.boxplot(df, ax=axes[1])
    plt.show()

# %%
# подготовим столбцы для построения граффиков
# категориальные столбцы
cat_cols = data_train.select_dtypes(include='object').columns.tolist()
# числовые столбцы
num_cols = data_train.select_dtypes(exclude='object').columns.tolist()

# %%
# тренировочные данные
for column in data_train[num_cols]:
    show_num_features(data_train[column], column, num_bins=30)

# %% [markdown]
# __Вывод:__
# 1) В даннах есть выбросы и аномальные значения, которые стоит изучить подробнее.
#
# 2) Акустичность и инструментальнсоть имеют очень много 0-х значений. Нахожу это довольно странным, но такое значениме вполне можеть быть. Диапазон у акустичности и инструментальность от 0 до 1.
#
# 3) Значениме длительность композиции -1 невозможно и является аномалией. Стоит поработать над этим признаком.
#
# 4) Громкость имеет значения больше 0. Что довольон не типично, так как обычно диапазон громкости от -60 до 0.

# %% [markdown]
# __Посмотрим на acousticness, относительно energy__

# %%
data_train[['music_genre','energy','acousticness']].groupby('music_genre').\
                                                    agg(['max', 
                                                         'min', 
                                                         'mean', 
                                                         'median', 
                                                         'var'])
# Out:
#             energy                                      acousticness  \
#                max      min      mean  median       var          max
# music_genre
# Alternative  0.997  0.05560  0.709903  0.7500  0.043582        0.984
# Anime        0.999  0.00243  0.675680  0.7980  0.087628        0.996
# Blues        0.998  0.00957  0.614845  0.6365  0.051155        0.995
# Classical    0.990  0.00101  0.173595  0.1000  0.048578        0.996
# Country      0.981  0.04270  0.635950  0.6680  0.039103        0.971
# Electronic   0.999  0.02110  0.738290  0.7720  0.035970        0.984
# Hip-Hop      0.995  0.19600  0.644255  0.6530  0.022959        0.953
# Jazz         0.993  0.01410  0.471345  0.4720  0.057340        0.996
# Rap          0.997  0.07930  0.649656  0.6460  0.023951        0.942
# Rock         0.997  0.02310  0.681844  0.7150  0.041103        0.994
#
#
#                   min      mean  median       var
# music_genre
# Alternative  0.000001  0.167049  0.0319  0.060885
# ...

# %%
# средняя акустика
round(data_train['acousticness'].mean(), 2)
# Out:
# 0.28

# %% [markdown]
# __Вывод:__ Жанры с высокоэнергетическими песнями производят низкую акустику, и наоборот. Средняя акустика по всему набору данных составляет 0.28.

# %% [markdown]
# __Посмотрим на danceability относительно energy__

# %%
data_train[['music_genre', 'energy', 'danceability']].groupby('music_genre').\
                                                      agg(['max', 
                                                           'min', 
                                                           'mean', 
                                                           'median', 
                                                           'var'])
# Out:
#             energy                                      danceability          \
#                max      min      mean  median       var          max     min
# music_genre
# Alternative  0.997  0.05560  0.709903  0.7500  0.043582        0.949  0.1030
# Anime        0.999  0.00243  0.675680  0.7980  0.087628        0.888  0.0606
# Blues        0.998  0.00957  0.614845  0.6365  0.051155        0.955  0.1180
# Classical    0.990  0.00101  0.173595  0.1000  0.048578        0.756  0.0600
# Country      0.981  0.04270  0.635950  0.6680  0.039103        0.953  0.2030
# Electronic   0.999  0.02110  0.738290  0.7720  0.035970        0.969  0.0822
# Hip-Hop      0.995  0.19600  0.644255  0.6530  0.022959        0.978  0.2840
# Jazz         0.993  0.01410  0.471345  0.4720  0.057340        0.955  0.0644
# Rap          0.997  0.07930  0.649656  0.6460  0.023951        0.975  0.2190
# Rock         0.997  0.02310  0.681844  0.7150  0.041103        0.883  0.0789
#
#
# ...

# %%
round(data_train['danceability'].mean(), 2)
# Out:
# 0.56

# %% [markdown]
# __Вывод:__ Anime и Classical имеют низкую танцевальность. Средняя танцеввальность составляет 0.56.

# %% [markdown]
# __Посмотрим на duration_ms__

# %%
display(data_train[data_train['duration_ms'] < 0])
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 73565.0       0.11000         0.470         -1.0  0.6410          0.000000
# 87453.0       0.99100         0.154         -1.0  0.0384          0.902000
# 76827.0       0.08480         0.748         -1.0  0.7120          0.000000
# 43888.0       0.05400         0.482         -1.0  0.6270          0.000003
# 39574.0       0.90900         0.374         -1.0  0.2270          0.000069
# ...               ...           ...          ...     ...               ...
# 48460.0       0.00298         0.450         -1.0  0.9150          0.446000
# 23677.0       0.98200         0.372         -1.0  0.1590          0.000001
# 89832.0       0.96600         0.638         -1.0  0.0689          0.000001
# 73890.0       0.62700         0.461         -1.0  0.4360          0.892000
# 47396.0       0.71900         0.725         -1.0  0.4830          0.000000
#
# ...

# %%
# медиана продолжительности
med_duration = data_train['duration_ms'].median()
# заполним аномальное значение длительнотиь -1 медианой
data_train.loc[data_train['duration_ms'] < 0, 'duration_ms'] = med_duration

# %% [markdown]
# __Вывод:__ В данных встречается много аномальных значений, 10%. Установить возмодную причину сложно. Значение -1 попадается во всех жанрах. Скорее всего ошибка записи данных. Возмодно это зависит от конкретного дня записми данных. проверим нашу теорию.

# %%
# посмотрим аномальные значения по датам
display(train.groupby('duration_ms')['obtained_date'].value_counts())
# Out:
# duration_ms  obtained_date
# -1.0         4-Apr            1804
#              3-Apr             163
#              5-Apr              25
#              1-Apr              10
#  15509.0     5-Apr               1
#                               ...
#  1778440.0   4-Apr               1
#  2019293.0   4-Apr               1
#  2764934.0   4-Apr               1
#  4276000.0   4-Apr               1
#  4497994.0   4-Apr               1
# Name: obtained_date, Length: 14236, dtype: int64

# %% [markdown]
# __Вывод:__ От конркетного дня записи это тоже никак не засисит. Тем не менее 10% аномальных значений достаточно много. Стоит попробовать установить причину.

# %% [markdown]
# __Посмотрим на instrumentalness__

# %%
display(data_train.groupby('instrumentalness')['music_genre'].value_counts())
# Out:
# instrumentalness  music_genre
# 0.000             Rap            1487
#                   Country        1005
#                   Alternative     712
#                   Hip-Hop         680
#                   Rock            591
#                                  ...
# 0.986             Electronic        1
# 0.987             Anime             1
#                   Classical         1
# 0.988             Anime             1
# 0.996             Anime             1
# Name: music_genre, Length: 10437, dtype: int64

# %%
data_train[['music_genre', 'energy', 'instrumentalness']].groupby('music_genre').\
                                                          agg(['max', 
                                                               'min', 
                                                               'mean',
                                                               'median', 
                                                               'var'])
# Out:
#             energy                                      instrumentalness       \
#                max      min      mean  median       var              max  min
# music_genre
# Alternative  0.997  0.05560  0.709903  0.7500  0.043582            0.935  0.0
# Anime        0.999  0.00243  0.675680  0.7980  0.087628            0.996  0.0
# Blues        0.998  0.00957  0.614845  0.6365  0.051155            0.961  0.0
# Classical    0.990  0.00101  0.173595  0.1000  0.048578            0.987  0.0
# Country      0.981  0.04270  0.635950  0.6680  0.039103            0.778  0.0
# Electronic   0.999  0.02110  0.738290  0.7720  0.035970            0.986  0.0
# Hip-Hop      0.995  0.19600  0.644255  0.6530  0.022959            0.923  0.0
# Jazz         0.993  0.01410  0.471345  0.4720  0.057340            0.975  0.0
# Rap          0.997  0.07930  0.649656  0.6460  0.023951            0.922  0.0
# Rock         0.997  0.02310  0.681844  0.7150  0.041103            0.973  0.0
#
#
# ...

# %%
round(data_train['instrumentalness'].mean(), 2)
# Out:
# 0.16

# %% [markdown]
# __Вывод:__ За некоторыми исключениями, жанры с высокоэнергетическими песнями производят низкую интсрументальность. Cредняя инструментальность 0.16

# %% [markdown]
# __Посмотрим на аномальную громкость__

# %%
data_train[data_train['loudness'] > 0]
# Out:
#          acousticness  danceability  duration_ms  energy  instrumentalness  \
# 22744.0      0.001870         0.774     248571.0   0.944          0.191000
# 36234.0      0.014700         0.497     184552.0   0.990          0.000000
# 87982.0      0.075600         0.345     256067.0   0.998          0.000018
# 33508.0      0.000467         0.186     294467.0   0.997          0.020200
# 83526.0      0.021800         0.629     196800.0   0.986          0.130000
# 67401.0      0.000945         0.748     247286.0   0.965          0.000631
# 54927.0      0.000032         0.297     218240.0   0.954          0.000055
# 86618.0      0.010200         0.646     164960.0   0.977          0.769000
# 32191.0      0.007800         0.598     336107.0   0.978          0.000025
# 83560.0      0.015900         0.682     313600.0   0.951          0.000993
# 83794.0      0.000886         0.287     228933.0   0.991          0.000000
# ...

# %%
# медиана громкости
med_loudness = data_train['loudness'].median()
# заполним данные медианом громкости 
data_train.loc[data_train['loudness'] > 0, 'loudness'] = med_loudness

# %% [markdown]
# #### Data test

# %%
# построим граффики для тестового датасета
for column in data_train[num_cols]:
    show_num_features(data_test[column], column, num_bins=30)

# %% [markdown]
# __Вывод:__
# 1) Мы видим, что как и в тренировочнрм датасете, в тестовосм тожде много значений 0 в акустичности и инструментальности.
#
# 2) В даннах есть выбросы и аномальные значения, которые стоит изучить подробнее.
#
# 3) Продолжительность песни имеент аномальные значения -1, а так же непонятный всплеск около 0.
#
# 4) Громкость иммет значения больше 0, как и в тренировочном наборе данных.

# %% [markdown]
# __Посмотрим на duration_ms__

# %%
# продолжительность музыкальной композиции < 0
display(data_test[data_test['duration_ms'] < 0])
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 72636      0.000335         0.421         -1.0  0.4470          0.014800   D
# 50963      0.000031         0.541         -1.0  0.9910          0.068200   F
# 30932      0.150000         0.725         -1.0  0.5520          0.000000   B
# 32598      0.674000         0.746         -1.0  0.3380          0.000375   B
# 79739      0.069800         0.564         -1.0  0.7340          0.000000  G#
# ...             ...           ...          ...     ...               ...  ..
# 47579      0.925000         0.484         -1.0  0.0697          0.000000  C#
# 63170      0.945000         0.487         -1.0  0.3060          0.721000   G
# 58698      0.259000         0.799         -1.0  0.5950          0.000000   D
# 26757      0.095900         0.829         -1.0  0.8780          0.000000   A
# 30767      0.011100         0.899         -1.0  0.6820          0.000000  A#
#
# ...

# %%
# заполним аномалии длительности -1 медианой
data_test.loc[data_test['duration_ms'] < 0, 'duration_ms'] = med_duration

# %% [markdown]
# Посмотрим на loudness

# %%
display(data_test[data_test['loudness'] > 0])
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 50650       0.00303         0.643     260571.0   0.927          0.003750  C#
# 78713       0.00258         0.589     257600.0   0.982          0.011200   C
# 25755       0.03460         0.491     177633.0   0.993          0.000005  C#
# 40477       0.09000         0.483     200400.0   0.995          0.000277   D
# 43909       0.00217         0.335     146227.0   0.979          0.897000   F
#
#        liveness  loudness   mode  speechiness    tempo  valence  \
# 50650    0.0816     0.229  Major       0.1350  139.839   0.2440
# 78713    0.1890     0.598    NaN       0.3270  150.005   0.2840
# 25755    0.1050     0.454  Major       0.4700  149.802   0.5350
# 40477    0.3730     1.893  Major       0.2970  149.978   0.3780
# 43909    0.0988     1.949  Major       0.0759  121.296   0.0376
#
#        len_track_name
# 50650              14
# 78713               3
# 25755              12
# 40477               8
# ...

# %%
# заполним аномалии длительности медианой
data_test.loc[data_test['loudness'] > 0, 'loudness'] = med_loudness

# %% [markdown]
# ##### Посмотрим на корреляцию по жанрам признаком instrumentalness и speechiness

# %%
plt.figure(figsize=(15, 8))
plt.title('Kорреляция', fontsize=16)
sns.scatterplot(data=data_train, 
                x='instrumentalness', 
                y='speechiness', 
                hue='music_genre')
plt.xscale('log')
plt.yscale('log')
plt.show()

# %% [markdown]
# __Вывод:__ Каждый жанр имеет свою кaртину корреляции между признаками instrumentalness и speechiness.
#
# Лучше всего поддаются идентифткации такие жанры как: сlassical, rap. Хуже всего еlectronic.
#
# Это нам может пригодиться для создания синтетических признаков.

# %% [markdown]
# __Вывод:__ Проведена обработка аномальных значений столбца duration_ms. Убрали выбросы в столбце громкость. Удалили явные дубликаты. Так же ненужные для предсказания столбцы были удалены.

# %% [markdown]
# ## Шаг 3. Разработка модели ML

# %% [markdown]
# ### Посмотрим на баланс классов

# %%
# граффик баланса классов
genre_counts = data_train['music_genre'].value_counts()
labels=genre_counts.index
sns.set(font_scale = 1)
plt.figure(figsize=(8,8))

plt.pie(
    x=genre_counts, 
    labels=genre_counts.index,
    autopct='%1.2f%%',
    colors=sns.color_palette('Set2'),
    startangle=90,
    explode=[0, 0, 0.08, 0, 0, 0, 0, 0.12, 0, 0]
)
plt.title('Баланс класcов')
plt.show()

# %% [markdown]
# __Вывод:__ Наблюдаем дисбаланс класов класса Blues в три раза больше, чем Hip-Hop.

# %% [markdown]
# ### Подготовим выборку

# %%
# Разделим выборку на features и target
X_train = data_train.drop('music_genre', axis=1)
y_train = data_train['music_genre']

# %%
#Разделим столбцы по категориям
# категориальные столбцы
cat_cols = X_train.select_dtypes(include='object').columns.tolist()
# числовые столбцы
num_cols = X_train.select_dtypes(exclude='object').columns.tolist()

# %% [markdown]
# ### Создадим pipeline

# %%
num_pipeline = Pipeline(steps=[
    ('knn', KNNImputer(n_neighbors=5, weights='distance')),
    ('scale',StandardScaler())
])

cat_pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('one-hot',OneHotEncoder(drop='first', handle_unknown='error', sparse_output=False))
])

col_trans = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, num_cols),
    ('cat_pipeline', cat_pipeline, cat_cols)
    ],
    remainder='passthrough',
    n_jobs=-1)

# %% [markdown]
# ### LogisticRegression

# %%
# %%time
def objective(trial):    
    # Список гиперпараметров для перебора
    param = {
        'solver': trial.suggest_categorical('solveg', ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']),
        'C': trial.suggest_float('c', 0.001, 0.01),
        'max_iter': trial.suggest_int('max_iter', 500, 1000)
    }
                                
    # Определяю модель машинного обучения, которой передаются гиперпараметры
    estimator = LogisticRegression(**param, 
                                   class_weight='balanced', 
                                   n_jobs=-1,  
                                   random_state=RANDOM_STATE)

     # Добавим пайплайн
    clf_pipeline = Pipeline(steps=[
        ('col_trans', col_trans),
        ('model', estimator)
    ])
    clf_pipeline.fit(X_train, y_train)
    
    # Вычисляем f1_micro
    
    return cross_val_score(clf_pipeline, X_train, y_train, cv=3, scoring='f1_micro').mean()

# Подбираем гиперпараметров
sampler = TPESampler(consider_prior=True, multivariate=True, group=True)
optuna_logreg = optuna.create_study(study_name='LogReg', direction='maximize', sampler=sampler)
# Запускаем процесс подбора гиперпараметров
optuna_logreg.optimize(objective, n_trials=5, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2024-03-25 13:25:36,497] A new study created in memory with name: LogReg
#   0%|          | 0/5 [00:00<?, ?it/s]
# [I 2024-03-25 13:25:46,500] Trial 3 finished with value: 0.3695312888586882 and parameters: {'solveg': 'sag', 'c': 0.0028872966967713656, 'max_iter': 862}. Best is trial 3 with value: 0.3695312888586882.
# [I 2024-03-25 13:25:48,012] Trial 2 finished with value: 0.37530752051572236 and parameters: {'solveg': 'newton-cg', 'c': 0.009243491190827745, 'max_iter': 554}. Best is trial 2 with value: 0.37530752051572236.
# [I 2024-03-25 13:25:54,008] Trial 1 finished with value: 0.3738006718807676 and parameters: {'solveg': 'saga', 'c': 0.006626680910898873, 'max_iter': 664}. Best is trial 2 with value: 0.37530752051572236.
# [I 2024-03-25 13:25:54,632] Trial 4 finished with value: 0.3976092118062812 and parameters: {'solveg': 'liblinear', 'c': 0.006625848531515609, 'max_iter': 665}. Best is trial 4 with value: 0.3976092118062812.
# ...

# %%
# запишем метрику f1 
f1_micro_logreg = round(optuna_logreg.best_value, 2)
# лучшая метрика и параметры
print('F1_micro: ', round(optuna_logreg.best_value, 2))
print('best_params: ', optuna_logreg.best_params)
# Out:
# F1_micro:  0.4
# best_params:  {'solveg': 'liblinear', 'c': 0.006625848531515609, 'max_iter': 665}

# %% [markdown]
# ### RandomForestClassifier

# %%
# %%time
def objective(trial):
    # Список гиперпараметров для перебора
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 10, 1000),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'max_depth': trial.suggest_int('max_depth', 2, 15),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 15),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
    }
    
    # Определяю модель машинного обучения, которой передаются гиперпараметры
    estimator = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=-1, **param)
    
    # Добавим пайплайн
    clf_pipeline = Pipeline(steps=[
        ('col_trans', col_trans),
        ('model', estimator)
    ])
    clf_pipeline.fit(X_train, y_train)
    
    # Вычисляем f1_micro
    
    return cross_val_score(clf_pipeline, X_train, y_train, cv=3, scoring= 'f1_micro').mean()

# Подбираем гиперпараметров
sampler = TPESampler(consider_prior=True, multivariate=True, group=True)
optuna_rf = optuna.create_study(study_name='RF', direction="maximize", sampler=sampler)
# Запускаем процесс подбора гиперпараметров
optuna_rf.optimize(objective, n_trials=5, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2024-03-25 13:25:55,314] A new study created in memory with name: RF
#   0%|          | 0/5 [00:00<?, ?it/s]
# [I 2024-03-25 13:27:14,993] Trial 2 finished with value: 0.33567739914590994 and parameters: {'n_estimators': 445, 'criterion': 'gini', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 2 with value: 0.33567739914590994.
# [I 2024-03-25 13:28:15,304] Trial 0 finished with value: 0.47546388541729195 and parameters: {'n_estimators': 104, 'criterion': 'gini', 'max_depth': 14, 'max_features': None, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.47546388541729195.
# [I 2024-03-25 13:29:13,541] Trial 1 finished with value: 0.40981467893791024 and parameters: {'n_estimators': 577, 'criterion': 'gini', 'max_depth': 4, 'max_features': 'log2', 'min_samples_split': 7, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.47546388541729195.
# ...

# %%
# запишем метрику f1 
f1_micro_rf = round(optuna_rf.best_value, 2) # запишем метрику f1
# лучшая метрика и параметры
print('F1_micro: ', round(optuna_rf.best_value, 2))
print('best_params: ', optuna_rf.best_params)
# Out:
# F1_micro:  0.48
# best_params:  {'n_estimators': 960, 'criterion': 'entropy', 'max_depth': 12, 'max_features': None, 'min_samples_split': 15, 'min_samples_leaf': 1}

# %% [markdown]
# 0.486758207531286
# {'n_estimators': 829, 'criterion': 'gini', 'max_depth': 14, 'max_features': 'log2', 'min_samples_split': 14, 'min_samples_leaf': 1}

# %% [markdown]
# ### CatBoostClassifier

# %%
# %%time
def objective(trial):    
    # Список гиперпараметров для перебора
    param = {
        'depth': trial.suggest_int('depth', 1, 12),
        'boosting_type': trial.suggest_categorical('boosting_type', ['Ordered', 'Plain']),
        'bootstrap_type': trial.suggest_categorical('bootstrap_type', ['Bayesian', 'Bernoulli', 'MVS']),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2),
        'l2_leaf_reg': trial.suggest_int('l2_leaf_reg', 1, 7),
        'iterations': trial.suggest_int('iterations', 100, 500),
        'border_count': trial.suggest_int('border_count', 5, 20),
        'thread_count': trial.suggest_int('thread_count', 3, 4),
        'early_stopping_rounds': trial.suggest_int('early_stopping_rounds', 9, 10),
        'random_strength': trial.suggest_float('random_strength', 0.01, 1),
        'max_ctr_complexity': trial.suggest_int('max_ctr_complexity', 1, 3)
    }
                                
    # Определяю модель машинного обучения, которой передаются гиперпараметры
    estimator = CatBoostClassifier(**param, verbose=False, loss_function='MultiClass')

    # Добавляем пайплайны
    clf_pipeline = Pipeline(steps=[
            ('col_trans', col_trans),
            ('model', estimator)
        ]) 
    clf_pipeline.fit(X_train, y_train)
    
    # Вычисляем f1_micro
    return cross_val_score(clf_pipeline, X_train, y_train, cv=3, scoring= 'f1_micro').mean()

# Подбираем гиперпараметров
sampler = TPESampler(consider_prior=True, multivariate=True, group=True)
optuna_cbc = optuna.create_study(study_name='CBC', direction="maximize", sampler=sampler)
# Запускаем процесс подбора гиперпараметров
optuna_cbc.optimize(objective, n_trials=5, n_jobs=-1, show_progress_bar=True)
# Out:
# [I 2024-03-25 13:41:32,880] A new study created in memory with name: CBC
#   0%|          | 0/5 [00:00<?, ?it/s]
# Custom logger is already specified. Specify more than one logger at same time is not thread safe.Custom logger is already specified. Specify more than one logger at same time is not thread safe.Custom logger is already specified. Specify more than one logger at same time is not thread safe.
# [I 2024-03-25 13:42:36,112] Trial 3 finished with value: 0.4537647701046026 and parameters: {'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'learning_rate': 0.09148942441148594, 'l2_leaf_reg': 4, 'iterations': 317, 'border_count': 11, 'thread_count': 4, 'early_stopping_rounds': 9, 'random_strength': 0.49424478235940467, 'max_ctr_complexity': 3}. Best is trial 3 with value: 0.4537647701046026.
# ...

# %%
# запишем метрику f1 
f1_micro_cbc = round(optuna_cbc.best_value, 2)
# лучшая метрика и параметры
print('F1_micro: ', round(optuna_cbc.best_value, 2))
print('best_params: ', optuna_cbc.best_params)
# Out:
# F1_micro:  0.49
# best_params:  {'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS', 'learning_rate': 0.03814533327044639, 'l2_leaf_reg': 5, 'iterations': 243, 'border_count': 18, 'thread_count': 3, 'early_stopping_rounds': 10, 'random_strength': 0.8885095728915804, 'max_ctr_complexity': 3}

# %% [markdown]
# {'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'learning_rate': 0.06658249684346926, 'l2_leaf_reg': 4, 'iterations': 289, 'border_count': 14, 'thread_count': 3, 'early_stopping_rounds': 9, 'random_strength': 0.634683886285959, 'max_ctr_complexity': 1}

# %% [markdown]
# ### Cобирем результаты всех моделей в таблицу

# %%
# модели
model = ['LogisticRegression¶',\
         'RandomForestClassifier',
         'CatBoostClassifier']
# метрика f1
f1_micro = [f1_micro_logreg, f1_micro_rf, f1_micro_cbc]
# собирем в датафрейм
result = pd.DataFrame({'model': model, 'f1_micro': f1_micro})
# посмотрим на результат
display(result)
# Out:
#                     model  f1_micro
# 0     LogisticRegression¶      0.40
# 1  RandomForestClassifier      0.48
# 2      CatBoostClassifier      0.49

# %% [markdown]
# __Вывод:__ Лучшая всего показала себя модель CatBoost Classifier. Удалось добиться метрики F1_micro 0.49. Будем использовать ее для обучения.

# %% [markdown]
# ### Проверим значимость параметров

# %%
# сделаем pipeline
num_pipe = Pipeline(steps=[('knn', KNNImputer(n_neighbors=5, weights='distance')),
                           ('scaler', StandardScaler())])

cat_pipe = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
                           ('ohe', OneHotEncoder(drop = 'first', 
                                                 handle_unknown = 'error',
                                                 sparse_output=False))])

сol_trans = ColumnTransformer(transformers=[('num_trans', num_pipe, num_cols),
                                     ('cat_trans', cat_pipe, cat_cols)],
                             remainder = 'passthrough',
                             n_jobs = -1)
сol_trans.fit(X_train)
# Out:
# ColumnTransformer(n_jobs=-1, remainder='passthrough',
#                   transformers=[('num_trans',
#                                  Pipeline(steps=[('knn',
#                                                   KNNImputer(weights='distance')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['acousticness', 'danceability', 'duration_ms',
#                                   'energy', 'instrumentalness', 'liveness',
#                                   'loudness', 'speechiness', 'tempo', 'valence',
#                                   'len_track_name']),
#                                 ('cat_trans',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('ohe',
#                                                   OneHotEncoder(drop='first',
# ...

# %%
# трансформируем параметры
X_train = сol_trans.transform(X_train)

# %%
# лучшие параметры модели
best_params = optuna_cbc.best_params

# %%
# CatBoostClassifier с лучшими перематры
best_model = CatBoostClassifier(**best_params, verbose=False, loss_function='MultiClass')

# %%
# зафитим лучшую модель
best_model.fit(X_train, y_train)

# %%
# фунция для вытаскивыания имени параметры
def get_col_name(pipe) -> list:
    column_name = pd.DataFrame(pipe.get_feature_names_out())
    column_name = column_name[0].apply(lambda x: x.split('__'))
    column_name = column_name.apply(lambda x: x[1]).tolist()
    return column_name

# %%
# подготовим признаки для анализа важных факторов
X_expl = pd.DataFrame(X_train)
X_expl.columns = get_col_name(сol_trans)

# %%
# проанализируем важность признаков
explainer = shap.TreeExplainer(best_model)

shap_values = explainer.shap_values(X_expl)

shap.summary_plot(shap_values, X_expl, max_display=20, plot_type='bar')

# %% [markdown]
# __Вывод:__ Наиболее значимыми признаками являются: инструментальность, выразительность и танцевальность. Признаки, базовый ключ произведения, модальность и привлекательность, имеют малую ценности, можно попробовать их удалить.

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# ### Протестируем модель

# %%
# стандартизируем тестовую выборку
X_test = сol_trans.transform(data_test)

# %% [markdown]
# ### Делаем предсказания на тестовая выборке

# %% [markdown]
# Делаем предсказания и отправляем результаты работы модели на тесте.

# %%
predictions = best_model.predict(X_test)

# %%
data_test['music_genre'] = predictions

# %%
result = data_test['music_genre']

# %%
result.index.names = ['instance_id']

# %%
result.to_csv('result_music_genre.csv', header=True)

# %% [markdown]
# __Вывод:__
#
# 1) Был проанализирован датасет музыкального стримингового сервиса. В данные есть пропуска, выбросы, имеются аномальные значения, мультиколленираность и дубликаты.
#
# 2) По время предподготовки данных были заполнены пропуска и аномальные значения. Удалены выбросы в столбце loudness. Произведен подробный анализ признаков.
#
# 3) Была поставлена задача разработать модель, позволяющую классифицировать музыкальные произведения по жанрам. Для этого нами было исследовательно 2 модели. Лучше всех себя показала модель CatBoost  Classifier. F1_micro 0.49.
#
# 4) Были проанализирована выжность признаков. Наиболее значимыми признаками являются: громкость, инструментальность, выразительность и танцевальность. Признаки, базовый ключ произведения, модальность и привлекательность, имеют малую ценности, можно попробовать их удалить.
#
# 5) Для классифицикации музыкальных произведений по жанрам на тестовой выборке была выбрана модель CatBoost Classifier. Лучший показатель F1 micro которого удалось длобиться равен 0.49.
